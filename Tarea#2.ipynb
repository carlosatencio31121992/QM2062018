# %%
from RegLineal2018 import reg_lin
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,1,2,3,4,5])
y=2*x+4
reg=reg_lin()
a,b=reg.regresion_lineal(x,y)
reg.graficar(x,y)
print(a,b)
# Out:
# 4.0 2.0
